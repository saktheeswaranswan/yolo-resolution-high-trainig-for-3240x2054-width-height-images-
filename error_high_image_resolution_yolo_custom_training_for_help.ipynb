# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5955, done.
# remote: Total 5955 (delta 0), reused 0 (delta 0), pack-reused 5955
# Receiving objects: 100% (5955/5955), 6.37 MiB | 13.32 MiB/s, done.
# Resolving deltas: 100% (3932/3932), done.

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !nvidia-smi
# Out:
# Sat Jul  8 12:36:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DGPU -I/usr/local/cuda/include/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#   232 |         cudaThreadSynchronize();
#       |         ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:1052:57: note: declared here
#  1052 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#       |                                                         ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
# %cp -r "/content/drive/MyDrive/yolophd.zip" "/content/darknet/pcbdata"

# %%
# %cd /content/darknet/pcbdata/
# Out:
# /content/darknet/pcbdata

# %%
# !unzip yolophd.zip
# Out:
# Archive:  yolophd.zip
#    creating: yolo pcb defects/
#   inflating: yolo pcb defects/01_missing_hole_01.txt
#   inflating: yolo pcb defects/01_missing_hole_01.jpg
#   inflating: yolo pcb defects/01_missing_hole_02.txt
#   inflating: yolo pcb defects/01_missing_hole_04.txt
#   inflating: yolo pcb defects/01_missing_hole_05.txt
#   inflating: yolo pcb defects/01_missing_hole_06.txt
#   inflating: yolo pcb defects/01_missing_hole_07.txt
#   inflating: yolo pcb defects/01_missing_hole_12.txt
#   inflating: yolo pcb defects/01_missing_hole_13.txt
#   inflating: yolo pcb defects/01_missing_hole_14.txt
#   inflating: yolo pcb defects/01_missing_hole_16.txt
#   inflating: yolo pcb defects/01_missing_hole_17.txt
#   inflating: yolo pcb defects/01_missing_hole_18.txt
#   inflating: yolo pcb defects/01_missing_hole_19.txt
#   inflating: yolo pcb defects/01_missing_hole_20.txt
#   inflating: yolo pcb defects/01_mouse_bite_01.txt
#   inflating: yolo pcb defects/01_mouse_bite_03.txt
# ...

# %%
# %cp -r  /content/darknet/pcbdata/yolopcbdefects/*txt /content/darknet/datapcb/

# %%
# %cd /content
# Out:
# /content

# %%
# !python processin.py

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !./darknet detector train cfg/voc.data /content/darknet/cfg/yolov3.cfg /content/darknet/yolov3.weights
# Out:
# yolov3
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   420 x 420 x   3   ->   420 x 420 x  32  0.305 BFLOPs
#     1 conv     64  3 x 3 / 2   420 x 420 x  32   ->   210 x 210 x  64  1.626 BFLOPs
#     2 conv     32  1 x 1 / 1   210 x 210 x  64   ->   210 x 210 x  32  0.181 BFLOPs
#     3 conv     64  3 x 3 / 1   210 x 210 x  32   ->   210 x 210 x  64  1.626 BFLOPs
#     4 res    1                 210 x 210 x  64   ->   210 x 210 x  64
#     5 conv    128  3 x 3 / 2   210 x 210 x  64   ->   105 x 105 x 128  1.626 BFLOPs
#     6 conv     64  1 x 1 / 1   105 x 105 x 128   ->   105 x 105 x  64  0.181 BFLOPs
#     7 conv    128  3 x 3 / 1   105 x 105 x  64   ->   105 x 105 x 128  1.626 BFLOPs
#     8 res    5                 105 x 105 x 128   ->   105 x 105 x 128
#     9 conv     64  1 x 1 / 1   105 x 105 x 128   ->   105 x 105 x  64  0.181 BFLOPs
#    10 conv    128  3 x 3 / 1   105 x 105 x  64   ->   105 x 105 x 128  1.626 BFLOPs
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2023-07-08 13:02:33--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  18.0MB/s    in 14s
#
# 2023-07-08 13:02:48 (16.6 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
